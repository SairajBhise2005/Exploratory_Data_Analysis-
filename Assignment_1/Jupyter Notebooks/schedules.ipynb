# %%
import pandas as pd
df1 = pd.read_csv("C:\\Users\\Tiya\\Downloads\\schedules - schedules.csv")

# %%
df1.head()
# Out:
#                   start_date                   end_date         day    status  \
# 0  2024-07-24T15:00:00+02:00  2024-07-24T16:45:00+02:00  2024-07-24  FINISHED
# 1  2024-07-24T15:00:00+02:00  2024-07-24T16:45:00+02:00  2024-07-24  FINISHED
# 2  2024-07-24T15:30:00+02:00  2024-07-24T15:46:00+02:00  2024-07-24  FINISHED
# 3  2024-07-24T16:00:00+02:00  2024-07-24T16:16:00+02:00  2024-07-24  FINISHED
# 4  2024-07-24T16:30:00+02:00  2024-07-24T16:46:00+02:00  2024-07-24  FINISHED
#
#      discipline discipline_code event  event_medal          phase gender  \
# 0      Football             FBL   Men            0  Men's Group B      M
# 1      Football             FBL   Men            0  Men's Group C      M
# 2  Rugby Sevens             RU7   Men            0   Men's Pool B      M
# 3  Rugby Sevens             RU7   Men            0   Men's Pool B      M
# 4  Rugby Sevens             RU7   Men            0   Men's Pool C      M
#
#   event_type                      venue venue_code  \
# 0      HTEAM  Geoffroy-Guichard Stadium        STE
# 1      HTEAM           Parc des Princes        PDP
# 2      HTEAM            Stade de France        STA
# 3      HTEAM            Stade de France        STA
# 4      HTEAM            Stade de France        STA
#
#                        location_description location_code  \
# 0  Geoffroy-Guichard Stadium, Saint-Etienne           STE
# 1                   Parc des Princes, Paris           PDP
# 2                           Stade de France           STA
# 3                           Stade de France           STA
# 4                           Stade de France           STA
#
#                                                  url
# 0   /en/paris-2024/results/football/men/gpb-000100--
# 1   /en/paris-2024/results/football/men/gpc-000100--
# 2  /en/paris-2024/results/rugby-sevens/men/gpb-00...
# 3  /en/paris-2024/results/rugby-sevens/men/gpb-00...
# 4  /en/paris-2024/results/rugby-sevens/men/gpc-00...

# %%
df=df1
print(df)
# Out:
#                      start_date                   end_date         day  \
# 0     2024-07-24T15:00:00+02:00  2024-07-24T16:45:00+02:00  2024-07-24
# 1     2024-07-24T15:00:00+02:00  2024-07-24T16:45:00+02:00  2024-07-24
# 2     2024-07-24T15:30:00+02:00  2024-07-24T15:46:00+02:00  2024-07-24
# 3     2024-07-24T16:00:00+02:00  2024-07-24T16:16:00+02:00  2024-07-24
# 4     2024-07-24T16:30:00+02:00  2024-07-24T16:46:00+02:00  2024-07-24
# ...                         ...                        ...         ...
# 3890  2024-08-11T13:44:00+02:00  2024-08-11T13:44:00+02:00  2024-08-11
# 3891  2024-08-11T13:56:00+02:00  2024-08-11T14:28:00+02:00  2024-08-11
# 3892  2024-08-11T14:00:00+02:00  2024-08-11T15:25:00+02:00  2024-08-11
# 3893  2024-08-11T15:30:00+02:00  2024-08-11T17:15:00+02:00  2024-08-11
# 3894  2024-08-11T21:00:00+02:00                        NaN  2024-08-11
#
#          status        discipline discipline_code           event  \
# 0      FINISHED          Football             FBL             Men
# 1      FINISHED          Football             FBL             Men
# 2      FINISHED      Rugby Sevens             RU7             Men
# 3      FINISHED      Rugby Sevens             RU7             Men
# 4      FINISHED      Rugby Sevens             RU7             Men
# ...         ...               ...             ...             ...
# 3890  CANCELLED     Cycling Track             CTR  Women's Sprint
# 3891   FINISHED     Cycling Track             CTR  Women's Omnium
# 3892   FINISHED        Water Polo             WPO             Men
# 3893   FINISHED        Basketball             BKB           Women
# 3894  SCHEDULED  Closing Ceremony             CER             NaN
#
#       event_medal                            phase gender event_type  \
# 0               0                    Men's Group B      M      HTEAM
# 1               0                    Men's Group C      M      HTEAM
# 2               0                     Men's Pool B      M      HTEAM
# 3               0                     Men's Pool B      M      HTEAM
# 4               0                     Men's Pool C      M      HTEAM
# ...           ...                              ...    ...        ...
# 3890            0           Women's Sprint, Finals      W        ATH
# 3891            1  Women's Omnium, Points Race 4/4      W        ATH
# 3892            1                     Men's Finals      M      HTEAM
# 3893            1                   Women's Finals      W      HTEAM
# 3894            0                              NaN    NaN        NaN
#
#                           venue venue_code  \
# 0     Geoffroy-Guichard Stadium        STE
# 1              Parc des Princes        PDP
# 2               Stade de France        STA
# 3               Stade de France        STA
# 4               Stade de France        STA
# ...                         ...        ...
# 3890         National Velodrome        VE1
# 3891         National Velodrome        VE1
# 3892     Paris La Defense Arena        DEF
# 3893                Bercy Arena        BCY
# 3894                        NaN        NaN
#
#                           location_description location_code  \
# 0     Geoffroy-Guichard Stadium, Saint-Etienne           STE
# 1                      Parc des Princes, Paris           PDP
# 2                              Stade de France           STA
# 3                              Stade de France           STA
# 4                              Stade de France           STA
# ...                                        ...           ...
# 3890       Saint-Quentin-en-Yvelines Velodrome           VE1
# 3891       Saint-Quentin-en-Yvelines Velodrome           VE1
# 3892                    Paris La Defense Arena           DEF
# 3893                               Bercy Arena           BCY
# 3894                                       NaN           NaN
#
#                                                     url
# 0      /en/paris-2024/results/football/men/gpb-000100--
# 1      /en/paris-2024/results/football/men/gpc-000100--
# 2     /en/paris-2024/results/rugby-sevens/men/gpb-00...
# 3     /en/paris-2024/results/rugby-sevens/men/gpb-00...
# 4     /en/paris-2024/results/rugby-sevens/men/gpc-00...
# ...                                                 ...
# 3890                                                NaN
# 3891  /en/paris-2024/results/cycling-track/women-s-o...
# 3892  /en/paris-2024/results/water-polo/men/fnl-0001...
# 3893  /en/paris-2024/results/basketball/women/fnl-00...
# 3894  /en/news/jo-paris-2024-ceremonie-cloture-stade...
#
# [3895 rows x 16 columns]

# %%
df.shape
# Out:
# (3895, 16)

# %%
df.head()
# Out:
#                   start_date                   end_date         day    status  \
# 0  2024-07-24T15:00:00+02:00  2024-07-24T16:45:00+02:00  2024-07-24  FINISHED
# 1  2024-07-24T15:00:00+02:00  2024-07-24T16:45:00+02:00  2024-07-24  FINISHED
# 2  2024-07-24T15:30:00+02:00  2024-07-24T15:46:00+02:00  2024-07-24  FINISHED
# 3  2024-07-24T16:00:00+02:00  2024-07-24T16:16:00+02:00  2024-07-24  FINISHED
# 4  2024-07-24T16:30:00+02:00  2024-07-24T16:46:00+02:00  2024-07-24  FINISHED
#
#      discipline discipline_code event  event_medal          phase gender  \
# 0      Football             FBL   Men            0  Men's Group B      M
# 1      Football             FBL   Men            0  Men's Group C      M
# 2  Rugby Sevens             RU7   Men            0   Men's Pool B      M
# 3  Rugby Sevens             RU7   Men            0   Men's Pool B      M
# 4  Rugby Sevens             RU7   Men            0   Men's Pool C      M
#
#   event_type                      venue venue_code  \
# 0      HTEAM  Geoffroy-Guichard Stadium        STE
# 1      HTEAM           Parc des Princes        PDP
# 2      HTEAM            Stade de France        STA
# 3      HTEAM            Stade de France        STA
# 4      HTEAM            Stade de France        STA
#
#                        location_description location_code  \
# 0  Geoffroy-Guichard Stadium, Saint-Etienne           STE
# 1                   Parc des Princes, Paris           PDP
# 2                           Stade de France           STA
# 3                           Stade de France           STA
# 4                           Stade de France           STA
#
#                                                  url
# 0   /en/paris-2024/results/football/men/gpb-000100--
# 1   /en/paris-2024/results/football/men/gpc-000100--
# 2  /en/paris-2024/results/rugby-sevens/men/gpb-00...
# 3  /en/paris-2024/results/rugby-sevens/men/gpb-00...
# 4  /en/paris-2024/results/rugby-sevens/men/gpc-00...

# %%
df.tail()
# Out:
#                      start_date                   end_date         day  \
# 3890  2024-08-11T13:44:00+02:00  2024-08-11T13:44:00+02:00  2024-08-11
# 3891  2024-08-11T13:56:00+02:00  2024-08-11T14:28:00+02:00  2024-08-11
# 3892  2024-08-11T14:00:00+02:00  2024-08-11T15:25:00+02:00  2024-08-11
# 3893  2024-08-11T15:30:00+02:00  2024-08-11T17:15:00+02:00  2024-08-11
# 3894  2024-08-11T21:00:00+02:00                        NaN  2024-08-11
#
#          status        discipline discipline_code           event  \
# 3890  CANCELLED     Cycling Track             CTR  Women's Sprint
# 3891   FINISHED     Cycling Track             CTR  Women's Omnium
# 3892   FINISHED        Water Polo             WPO             Men
# 3893   FINISHED        Basketball             BKB           Women
# 3894  SCHEDULED  Closing Ceremony             CER             NaN
#
#       event_medal                            phase gender event_type  \
# 3890            0           Women's Sprint, Finals      W        ATH
# 3891            1  Women's Omnium, Points Race 4/4      W        ATH
# 3892            1                     Men's Finals      M      HTEAM
# 3893            1                   Women's Finals      W      HTEAM
# 3894            0                              NaN    NaN        NaN
#
#                        venue venue_code                 location_description  \
# 3890      National Velodrome        VE1  Saint-Quentin-en-Yvelines Velodrome
# 3891      National Velodrome        VE1  Saint-Quentin-en-Yvelines Velodrome
# 3892  Paris La Defense Arena        DEF               Paris La Defense Arena
# 3893             Bercy Arena        BCY                          Bercy Arena
# 3894                     NaN        NaN                                  NaN
#
#      location_code                                                url
# 3890           VE1                                                NaN
# 3891           VE1  /en/paris-2024/results/cycling-track/women-s-o...
# 3892           DEF  /en/paris-2024/results/water-polo/men/fnl-0001...
# 3893           BCY  /en/paris-2024/results/basketball/women/fnl-00...
# 3894           NaN  /en/news/jo-paris-2024-ceremonie-cloture-stade...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3895 entries, 0 to 3894
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   start_date            3895 non-null   object
#  1   end_date              3893 non-null   object
#  2   day                   3895 non-null   object
#  3   status                3895 non-null   object
#  4   discipline            3895 non-null   object
#  5   discipline_code       3895 non-null   object
#  6   event                 3893 non-null   object
#  7   event_medal           3895 non-null   int64
#  8   phase                 3893 non-null   object
#  9   gender                3893 non-null   object
#  10  event_type            3893 non-null   object
#  11  venue                 3893 non-null   object
#  12  venue_code            3893 non-null   object
#  13  location_description  3893 non-null   object
#  14  location_code         3893 non-null   object
#  15  url                   3810 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 487.0+ KB

# %%
df.isnull().sum() #finds the sum of missing values , plays a cruitial role as it gives many insights
# Out:
# start_date               0
# end_date                 2
# day                      0
# status                   0
# discipline               0
# discipline_code          0
# event                    2
# event_medal              0
# phase                    2
# gender                   2
# event_type               2
# venue                    2
# venue_code               2
# location_description     2
# location_code            2
# url                     85
# dtype: int64

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Find rows where 'gender' column has missing values
missing_gender_rows = df[df['gender'].isna()]

# Display the rows with missing 'gender' values
print(missing_gender_rows)
# Out:
#                      start_date end_date         day     status  \
# 49    2024-07-26T20:00:00+02:00      NaN  2024-07-26   FINISHED
# 3894  2024-08-11T21:00:00+02:00      NaN  2024-08-11  SCHEDULED
#
#             discipline discipline_code event  event_medal phase gender  \
# 49    Opening Ceremony             CER   NaN            0   NaN    NaN
# 3894  Closing Ceremony             CER   NaN            0   NaN    NaN
#
#      event_type venue venue_code location_description location_code  \
# 49          NaN   NaN        NaN                  NaN           NaN
# 3894        NaN   NaN        NaN                  NaN           NaN
#
#                                                     url
# 49    /en/paris-2024/the-games/ceremonies/opening-ce...
# 3894  /en/news/jo-paris-2024-ceremonie-cloture-stade...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Find rows where 'gender' column has missing values
missing_gender_rows = df[df['venue'].isna()]

# Display the rows with missing 'gender' values
print(missing_gender_rows)
# Out:
#                      start_date end_date         day     status  \
# 49    2024-07-26T20:00:00+02:00      NaN  2024-07-26   FINISHED
# 3894  2024-08-11T21:00:00+02:00      NaN  2024-08-11  SCHEDULED
#
#             discipline discipline_code event  event_medal phase gender  \
# 49    Opening Ceremony             CER   NaN            0   NaN    NaN
# 3894  Closing Ceremony             CER   NaN            0   NaN    NaN
#
#      event_type venue venue_code location_description location_code  \
# 49          NaN   NaN        NaN                  NaN           NaN
# 3894        NaN   NaN        NaN                  NaN           NaN
#
#                                                     url
# 49    /en/paris-2024/the-games/ceremonies/opening-ce...
# 3894  /en/news/jo-paris-2024-ceremonie-cloture-stade...

# %%
df.describe()
# Out:
#        event_medal
# count  3895.000000
# mean      0.213864
# std       0.653475
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.000000

# %%
df.dtypes # helps to find if qualitative or quantitative
# Out:
# start_date              object
# end_date                object
# day                     object
# status                  object
# discipline              object
# discipline_code         object
# event                   object
# event_medal              int64
# phase                   object
# gender                  object
# event_type              object
# venue                   object
# venue_code              object
# location_description    object
# location_code           object
# url                     object
# dtype: object

# %%
numerical=df.select_dtypes(include=['int64','float64']).columns #df.select used to select 
print("numerical features are",numerical.tolist())
categor=df.select_dtypes(include=['category','object','bool']).columns  
print("categorical features are",categor.tolist())
# Out:
# numerical features are ['event_medal']
# categorical features are ['day', 'status', 'discipline', 'discipline_code', 'event', 'phase', 'gender', 'event_type', 'venue', 'venue_code', 'location_description', 'location_code', 'url']

# %%
#######################
df.nunique()
df['start_date'].unique()
# Out:
# array(['2024-07-24T15:00:00+02:00', '2024-07-24T15:30:00+02:00',
#        '2024-07-24T16:00:00+02:00', ..., '2024-08-11T14:00:00+02:00',
#        '2024-08-11T15:30:00+02:00', '2024-08-11T21:00:00+02:00'],
#       dtype=object)

# %%
df['venue'].value_counts()
# Out:
# venue
# Champ-de-Mars Arena          786
# Grand Palais                 442
# Roland-Garros Stadium        235
# La Chapelle Arena            212
# North Paris Arena            210
# Stade de France              202
# Marseille Marina             186
# South Paris Arena 4          182
# Invalides                    172
# Nautical St - Flat water     149
# La Concorde 1                133
# Paris La Defense Arena       121
# Eiffel Tower Stadium         108
# National Velodrome            80
# Yves-du-Manoir Stadium        76
# South Paris Arena 6           70
# Aquatics Centre               65
# Teahupo'o, Tahiti             64
# Chateauroux Shooting Ctr      54
# Pierre Mauroy Stadium         52
# South Paris Arena 1           52
# Château de Versailles         42
# Bercy Arena                   42
# Nautical St - White water     32
# Le Bourget Climbing Venue     18
# BMX Stadium                   16
# Lyon Stadium                  11
# Parc des Princes              10
# Marseille Stadium             10
# La Beaujoire Stadium           8
# Le Golf National               8
# Pont Alexandre III             7
# Bordeaux Stadium               7
# Geoffroy-Guichard Stadium      6
# Nice Stadium                   6
# Trocadéro                      5
# La Concorde 2                  4
# La Concorde 3                  4
# La Concorde 4                  4
# Elancourt Hill                 2
# Name: count, dtype: int64

# %%
df['location_code'].value_counts()
# Out:
# location_code
# JU1    276
# NPA    210
# WRB    177
# INV    172
# JU2    166
#       ...
# GA3      1
# GA7      1
# GA4      1
# GA8      1
# GA6      1
# Name: count, Length: 91, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# M    1940
# W    1791
# X     141
# O      21
# Name: count, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# discipline
# Judo                     442
# Wrestling                344
# Fencing                  284
# Boxing                   235
# Tennis                   208
# Badminton                206
# Sailing                  186
# Table Tennis             182
# Archery                  170
# Taekwondo                158
# Athletics                139
# Beach Volleyball         108
# Swimming                  91
# Rowing                    90
# Cycling Track             80
# Handball                  76
# Hockey                    76
# Water Polo                74
# Rugby Sevens              68
# 3x3 Basketball            68
# Breaking                  65
# Surfing                   64
# Canoe Sprint              59
# Football                  58
# Shooting                  54
# Basketball                52
# Volleyball                52
# Canoe Slalom              32
# Modern Pentathlon         26
# Artistic Gymnastics       22
# Equestrian                18
# Sport Climbing            18
# Cycling BMX Racing        16
# Diving                    16
# Weightlifting             10
# Golf                       8
# Skateboarding              8
# Rhythmic Gymnastics        6
# Artistic Swimming          5
# Trampoline Gymnastics      4
# Cycling BMX Freestyle      4
# Cycling Road               4
# Triathlon                  3
# Marathon Swimming          2
# Cycling Mountain Bike      2
# Opening Ceremony           1
# Closing Ceremony           1
# Name: count, dtype: int64

# %%
df.memory_usage(deep=True)
# Out:
# Index                      132
# start_date              288230
# end_date                288146
# day                     229805
# status                  222086
# discipline              223664
# discipline_code         202540
# event                   244070
# event_medal              31160
# phase                   298390
# gender                  194714
# event_type              206712
# venue                   259149
# venue_code              202500
# location_description    285306
# location_code           202500
# url                     413620
# dtype: int64

# %%
pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in d:\tiya.anaconda\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: matplotlib in d:\tiya.anaconda\lib\site-packages (3.8.4)
# Requirement already satisfied: seaborn in d:\tiya.anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\tiya.anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\tiya.anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\tiya.anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\tiya.anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\tiya.anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in d:\tiya.anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group by discipline to count the number of events per sport
event_distribution = df.groupby(['discipline', 'discipline_code'])['event'].count().reset_index()

# Sort the event count for better visualization
event_distribution = event_distribution.sort_values(by='event', ascending=False)

# Bar Chart
plt.figure(figsize=(12, 8))  # Increased figure size for better readability
sns.barplot(x='event', y='discipline', data=event_distribution, palette='viridis')

plt.title('Event Distribution by Discipline (Sport Type)', fontsize=14)  # Larger title font
plt.xlabel('Number of Events', fontsize=12)  # Label for x-axis
plt.ylabel('Sport (Discipline)', fontsize=12)  # Label for y-axis
plt.xticks(fontsize=10)  # Font size for x-ticks
plt.yticks(fontsize=10, rotation=0)  # Font size and rotation for y-ticks

plt.tight_layout()  # Adjust the layout to make everything fit
plt.show()
# Out:
# C:\Users\Tiya\AppData\Local\Temp\ipykernel_14904\2065529811.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='event', y='discipline', data=event_distribution, palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'day' column to datetime if it's not already in datetime format
df['day'] = pd.to_datetime(df['day'])

# Group by day and status, and count the number of events
event_status_over_time = df.groupby(['day', 'status']).size().unstack(fill_value=0)

# Time Series Plot (Stacked Bar Chart)
plt.figure(figsize=(12, 8))
event_status_over_time.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='viridis')

plt.title('Event Status Over Time', fontsize=16)
plt.xlabel('Day', fontsize=12)
plt.ylabel('Number of Events', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.legend(title='Event Status', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
df['start_date'] = pd.to_datetime(df['start_date'])
df['end_date'] = pd.to_datetime(df['end_date'])

# Extract the day from the start_date (assuming daily granularity)
df['day'] = df['start_date'].dt.date

# Group by venue and day to count how many events are held in each venue per day
venue_utilization = df.groupby(['venue', 'day']).size().unstack(fill_value=0)

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(venue_utilization, cmap='YlGnBu', linewidths=0.5)

# Title and labels
plt.title('Venue Utilization Across Days', fontsize=16)
plt.xlabel('Day', fontsize=12)
plt.ylabel('Venue', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by gender and discipline to count events
event_count_gender = df.groupby(['discipline', 'gender'])['event'].count().unstack()

# Define a color palette for 4 genders
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Blue, Orange, Green, Red

# Plotting a stacked bar chart with 4 genders
plt.figure(figsize=(14, 8))  # Increase the figure size
event_count_gender.plot(kind='bar', stacked=True, figsize=(14, 8), color=colors)

# Adjust the x-axis labels
plt.title('Event Count by Gender and Discipline', fontsize=16)
plt.xlabel('Discipline', fontsize=12)
plt.ylabel('Number of Events', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)  # Rotate x-axis labels and align them to the right
plt.legend(title='Gender', loc='upper right')
plt.tight_layout()  # Ensure that everything fits into the plot neatly
plt.show()

# %%
# $ Count total events for each gender
gender_event_count = df['gender'].value_counts()

# Plotting a pie chart
gender_event_count.plot(kind='pie', autopct='%1.1f%%', colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'], figsize=(6, 6))
plt.title('Total Event Count by Gender', fontsize=16)
plt.ylabel('')  # Hides the y-axis label
plt.show()

# %%
# Group by venue and gender to count events 
venue_usage_gender = df.groupby(['venue', 'gender'])['event'].count().unstack().fillna(0)

# Plotting a stacked bar chart
venue_usage_gender.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])  # Added more colors
plt.title('Venue Usage by Gender', fontsize=16)
plt.xlabel('Venue', fontsize=12)
plt.ylabel('Number of Events', fontsize=12)

# Rotating labels and aligning them to prevent overlap
plt.xticks(rotation=70, ha='right')

plt.legend(title='Gender', loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Group by gender and sum the number of events
gender_distribution = df.groupby('gender')['event'].count()

# Plotting a pie chart for gender distribution
plt.figure(figsize=(4, 4))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct='%1.1f%%', startangle=90, colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])
plt.title('Event Distribution by Gender', fontsize=16)
plt.axis('equal')  # Ensures the pie chart is a circle
plt.tight_layout()
plt.show()

# %%
#medals won at each venue
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset already contains a column 'event_medal' 
# where 1 represents a medal being awarded and 0 represents no medal.

# Group by venue and sum the medals won at each venue
medals_by_venue = df.groupby('venue')['event_medal'].sum().reset_index()

# Sort the venues by the number of medals
medals_by_venue = medals_by_venue.sort_values(by='event_medal', ascending=False)

# Plotting the bar chart for medals won at each venue
plt.figure(figsize=(7, 7))
plt.barh(medals_by_venue['venue'], medals_by_venue['event_medal'], color='c')

# Adding labels and title
plt.xlabel('Number of Medals', fontsize=12)
plt.ylabel('Venue', fontsize=12)
plt.title('Number of Medals Won at Each Venue', fontsize=16)

# Rotate venue names on the y-axis for better readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by venue and sum the medals won at each venue
medals_by_venue = df.groupby('venue')['event_medal'].sum().reset_index()

# Sort the venues by the number of medals
medals_by_venue = medals_by_venue.sort_values(by='event_medal', ascending=False)

# Plotting the horizontal bar chart for medals won at each venue
plt.figure(figsize=(7, 7))
plt.barh(medals_by_venue['venue'], medals_by_venue['event_medal'], color='c')

# Adding labels and title
plt.xlabel('Number of Medals', fontsize=12)
plt.ylabel('Venue', fontsize=12)
plt.title('Number of Medals Won at Each Venue', fontsize=16)

# Ensure the layout is tight for better readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Find rows where 'gender' column has missing values
missing_gender_rows = df[df['gender'].isna()]

# Display the rows with missing 'gender' values
print(missing_gender_rows)
# Out:
#                     start_date end_date         day     status  \
# 49   2024-07-26 20:00:00+02:00      NaT  2024-07-26   FINISHED
# 3894 2024-08-11 21:00:00+02:00      NaT  2024-08-11  SCHEDULED
#
#             discipline discipline_code event  event_medal phase gender  \
# 49    Opening Ceremony             CER   NaN            0   NaN    NaN
# 3894  Closing Ceremony             CER   NaN            0   NaN    NaN
#
#      event_type venue venue_code location_description location_code  \
# 49          NaN   NaN        NaN                  NaN           NaN
# 3894        NaN   NaN        NaN                  NaN           NaN
#
#                                                     url
# 49    /en/paris-2024/the-games/ceremonies/opening-ce...
# 3894  /en/news/jo-paris-2024-ceremonie-cloture-stade...
